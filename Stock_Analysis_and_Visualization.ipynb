# %%
# !pip install yfinance beautifulsoup4 requests pandas matplotlib

# %%
import yfinance as yf
import pandas as pd

# Teslaの株価データを取得
tesla = yf.Ticker("TSLA")
tesla_stock_data = tesla.history(period="max")

# データの確認
tesla_stock_data.reset_index(inplace=True)
print(tesla_stock_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
import requests
from bs4 import BeautifulSoup

# Yahoo FinanceのTeslaの財務ページのURL
url = "https://finance.yahoo.com/quote/TSLA/financials/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# 表から収益データを抽出（適切な場所からテーブルを探して情報を抽出します）
# 以下は例として架空の方法ですが、実際の構造に基づいて修正が必要です
tables = soup.find_all("table")
# 必要に応じて、適切なテーブルから収益データを取り出す
tesla_revenue = pd.DataFrame()  # 必要に応じてデータ加工

print(tesla_revenue.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# テスラのティッカーシンボル "TSLA" を指定してデータを取得
tesla = yf.Ticker("TSLA")

# 財務データを取得
tesla_financials = tesla.financials

# データを表示
display(tesla_financials)
# Out:
#                                                        2023-12-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                           0.21
# Normalized EBITDA                                   14796000000.0
# Total Unusual Items                                           0.0
# Total Unusual Items Excluding Goodwill                        0.0
# Net Income From Continuing Operation Net Minori...  14999000000.0
# Reconciled Depreciation                              4667000000.0
# Reconciled Cost Of Revenue                          79113000000.0
# EBITDA                                              14796000000.0
# EBIT                                                10129000000.0
# Net Interest Income                                   910000000.0
# Interest Expense                                      156000000.0
# Interest Income                                      1066000000.0
# ...

# %%
# 'Total Revenue' という収益データを抽出
if 'Total Revenue' in tesla_financials.index:
    tesla_revenue = tesla_financials.loc['Total Revenue']
    # 最後の5行を表示
    print(tesla_revenue.tail())
else:
    print("Total Revenueデータが見つかりませんでした。データが財務情報に含まれていない可能性があります。")
# Out:
# 2023-12-31    96773000000.0
# 2022-12-31    81462000000.0
# 2021-12-31    53823000000.0
# 2020-12-31    31536000000.0
# 2019-12-31              NaN
# Name: Total Revenue, dtype: object

# %%
gme_data = yf.download("GME", start="2020-01-01", end="2023-01-01")

# インデックスをリセットして、最初の5行を表示
gme_data.reset_index(inplace=True)
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date Adj Close   Close    High     Low    Open  \
# Ticker                                 GME     GME     GME     GME     GME
# 0      2020-01-02 00:00:00+00:00    1.5775  1.5775  1.6175  1.5175  1.5350
# 1      2020-01-03 00:00:00+00:00    1.4700  1.4700  1.5625  1.4600  1.5525
# 2      2020-01-06 00:00:00+00:00    1.4625  1.4625  1.4775  1.4000  1.4500
# 3      2020-01-07 00:00:00+00:00    1.3800  1.3800  1.4575  1.3600  1.4425
# 4      2020-01-08 00:00:00+00:00    1.4300  1.4300  1.4625  1.3525  1.3725
#
# Price     Volume
# Ticker       GME
# 0       17814400
# 1       14175600
# 2       13579200
# 3       20912000
# 4       22517600

# %%
# GameStopのティッカーシンボル "GME" を指定して財務データを取得
gme = yf.Ticker("GME")
gme_financials = gme.financials

# 'Total Revenue' という収益データを抽出
if 'Total Revenue' in gme_financials.index:
    gme_revenue = gme_financials.loc['Total Revenue']
    # 最後の5行を表示
    print(gme_revenue.tail())
else:
    print("Total Revenueデータが見つかりませんでした。データが財務情報に含まれていない可能性があります。")
# Out:
# 2024-01-31    5272800000.0
# 2023-01-31    5927200000.0
# 2022-01-31    6010700000.0
# 2021-01-31    5089800000.0
# 2020-01-31             NaN
# Name: Total Revenue, dtype: object

# %%
import matplotlib.pyplot as plt
# Teslaの株価データを取得
tesla_data = yf.download("TSLA", start="2020-01-01", end="2023-01-01")

# グラフを作成する関数
def make_graph(stock_data, title="Stock Price Over Time"):
    plt.figure(figsize=(12, 6))
    plt.plot(stock_data.index, stock_data['Close'], label='Close Price')  # 終値をプロット
    plt.title(title)
    plt.xlabel("Date")
    plt.ylabel("Stock Price (USD)")
    plt.legend()
    plt.show()

# Teslaの株価グラフを作成
make_graph(tesla_data, title="Tesla Stock Price Over Time")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# GameStopの株価データを取得
gme_data = yf.download("GME", start="2020-01-01", end="2023-01-01")
# GameStopの株価グラフを作成
make_graph(gme_data, title="GameStop Stock Price Over Time")
# Out:
# [*********************100%***********************]  1 of 1 completed
