# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - Understand basic arithmetic operations in Python.
# - Learn how to convert time measurements (minutes to hours).
# - Explore the use of comments for code documentation.
# - Familiarize yourself with creating and executing code cells in a notebook.
# - Identify popular languages used in Data Science.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools         |
# |----------------------------|
# | Jupyter Notebook           |
# | RStudio                    |
# | Apache Zeppelin            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers.
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
hours = 200 / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Ken Furudate

# %% [markdown]
# # Exercise 1: Create a Jupyter Notebook
#
# - [x] Create a new Jupyter notebook called `DataScienceEcosystem.ipynb`

# %% [markdown]
# #### Exercise 2: Create markdown cell with title of the notebook
#
# - [x] Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading.
# - [x] Take a screenshot of the markdown cell and name it as 2-title.png

# %% [markdown]
# ![2-title.png](attachment:0917a6a1-e9d6-4010-b6a4-df60d6ec8400.png)

# %% [markdown]
# #### Exercise 3:  Create a markdown cell for an introduction
#
# - [x] Write an introductory sentence about the notebook such as the follows:
# - [x] Take a screenshot of the markdown cell and name it as 3-intro.png.

# %% [markdown]
# ![3-intro.png](attachment:6dff8d11-6786-4024-8702-839df4dcfb88.png)

# %% [markdown]
# #### Exercise 4:  Create a markdown cell to list data science languages
#
# - [x] Start the cell with an overview line such as:
# - [x] Then create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data science
# - [x] Take a screenshot of the markdown cell and name it as 4-dslanguages.png

# %% [markdown]
# ![4-dslanguages.png](attachment:3ebbf443-a5ca-4d01-9135-ca5c5cbc0720.png)

# %% [markdown]
# #### Exercise 5:  Create a markdown cell to list data science libraries
#
# - [x] Add an overview line to the cell like:
# - [x] Below this line add an ordered list listing 3 (or more) commonly used libraries in data science.
# - [x] Take a screenshot of the markdown cell and name it as 5-dslibraries.png

# %% [markdown]
# ![5-dslibraries.png](attachment:1cd57e0b-4d60-4526-b4a7-5d304083928c.png)

# %% [markdown]
# #### Exercise 6 - Create a markdown cell with a table of Data Science tools
#
# - [x] Create a single column table in this cell with the first row containing the header
# - [x] The subsequent three rows in the table should indicate three development environment open source tools used in data science.
# - [x] Take a screenshot of the markdown cell and name it as 6-dstools.png

# %% [markdown]
# ![6-dstools.png](attachment:e76b5e1e-f931-4238-82ec-eb685938c568.png)

# %% [markdown]
# #### Exercise 7 - Create a markdown cell introducing arithmetic expression examples
#
# - [x] Add a line in this cell with H3 style heading with text like:
# - [x] Take a screenshot of the markdown cell and name it as 7-introarithmetic.png

# %% [markdown]
# ![7-introarithmetic.png](attachment:b156dabf-a554-47f6-a2e5-ef3b49945c3a.png)

# %% [markdown]
# #### Exercise 8 - Create a code cell to multiply and add numbers
#
# - [x] In this code cell evaluate the expression (3*4)+5.
# - [x] Insert a comment line before the expression to explain the operation e.g.
# - [x] Then execute the cell to ensure the expression returns the expected output of
# - [x] Take a screenshot of the code cell with output and name it as 8-multiplyandaddintegers.png

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:ccb612e9-0326-40d6-8dd9-2e2c857c9431.png)

# %% [markdown]
# #### Exercise 9 - Create a code cell to convert minutes to hours
#
# - [x] In this code cell write an expression that converts 200 minutes into hours.
# - [x] Insert a comment line before the expression to explain the operation e.g.
# - [x] Run the cell to evaluate the expression.
# - [x] Take a screenshot of the code cell with output and name it as 9-hourstominutes.png

# %% [markdown]
# ![9-hourstominutes.png](attachment:7ffc4520-105e-43f7-b48a-27394aa59d68.png)

# %% [markdown]
# #### Exercise 10 - Insert a markdown cell to list Objectives
#
# - [x] Below the introduction cell created in Exercise 3, insert a new markdown cell to list the objectives that this notebook covered (i.e. some of the key takeaways from the course). In this new cell start with an introductory line titled: Objectives: in bold font. Then using an unordered list (bullets) indicate 3 to 5 items covered in this notebook,
# - [x] Take a screenshot of the markdown cell and name it as 10-objectives.png

# %% [markdown]
# ![10-objectives.png](attachment:03e091be-032e-4367-a717-8322eb48c92b.png)

# %% [markdown]
# #### Exercise 11 - Create a markdown cell to indicate the Author's name
#
# - [x] In this markdown cell markdown cell include the following text Author in H2 style heading. Include your name as regular text below the word Author
# - [x] Take a screenshot of the markdown cell and name it as 11-authordetails.png

# %% [markdown]
# ![11-authordetails.png](attachment:7415ce70-3913-448a-865e-69122e75612e.png)
